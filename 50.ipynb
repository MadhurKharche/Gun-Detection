# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.image import resize_with_pad
from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv2D, Dropout, LeakyReLU, MaxPooling2D, UpSampling2D

# %%
BASE_IMAGE_PATH = 'drive/My Drive/dataset/Images'
BASE_LABELS_PATH = 'drive/My Drive/dataset/Labels'
TARGET_IMAGE_SIZE = (256, 256)
LEARNING_RATE = 0.0001
BATCH_SIZE = 16
EPOCHS = 50
VAL_SPLIT = 0.2

# %%
from tqdm import tqdm

# %%
image_data = []
image_labels = []

image_count = len(os.listdir(BASE_IMAGE_PATH))

for i in tqdm(range(1, image_count + 1)):
    img = load_img(os.path.join(BASE_IMAGE_PATH, str(i) + '.jpeg'))
    img = img_to_array(img, dtype = 'uint8')
    image_data.append(img)
    
    label_mask = np.zeros((*img.shape[:2], 1))
    
    with open(os.path.join(BASE_LABELS_PATH, str(i) + '.txt'), 'r') as label_file:
        l_count = int(label_file.readline())
        
        for i in range(l_count):
            box = list(map(int, label_file.readline().split()))
            label_mask[box[1]:box[3], box[0]:box[2]] = 1.0
        
    image_labels.append(label_mask)
# Out:
# 100%|██████████| 333/333 [01:57<00:00,  2.83it/s]

# %%
plt.subplots(nrows = 2, ncols = 4, figsize = (20, 10))

for i, img_index in enumerate(np.random.randint(0, image_count, size = 4)):
    plt.subplot(2, 4, i + 1)
    plt.axis(False)
    plt.grid(False)
    plt.title(f'Image: {img_index}')
    plt.imshow(image_data[img_index])
    
    plt.subplot(2, 4, i + 5)
    plt.axis(False)
    plt.grid(False)
    plt.title(f'Label mask: {img_index}')
    plt.imshow(image_labels[img_index], cmap = 'gray')
plt.show()

# %%
for i in tqdm(range(image_count)):
    image_data[i] = resize_with_pad(image_data[i], *TARGET_IMAGE_SIZE).numpy() / 255.0
    image_labels[i] = resize_with_pad(image_labels[i], *TARGET_IMAGE_SIZE).numpy()
# Out:
# 100%|██████████| 333/333 [00:09<00:00, 35.86it/s]

# %%
plt.subplots(nrows = 2, ncols = 4, figsize = (20, 10))

for i, img_index in tqdm(enumerate(np.random.randint(0, image_count, size = 4))):
    plt.subplot(2, 4, i + 1)
    plt.axis(False)
    plt.grid(False)
    plt.title(f'Image: {img_index}')
    plt.imshow(image_data[img_index])
    
    plt.subplot(2, 4, i + 5)
    plt.axis(False)
    plt.grid(False)
    plt.title(f'Label mask: {img_index}')
    plt.imshow(image_labels[img_index], cmap = 'gray')
plt.show()
# Out:
# 4it [00:00, 233.51it/s]

# %%
image_data = np.array(image_data)
image_labels = np.array(image_labels)

# %%
def weighted_bce(y_true, y_pred):
    LOSS_WEIGHT = 8
    loss_ones = LOSS_WEIGHT * y_true * tf.math.log(y_pred + 1e-7)
    loss_zeros = (1 - y_true) * tf.math.log(1 - y_pred + 1e-7)
    loss = - loss_ones - loss_zeros
    return tf.reduce_mean(loss)

# %%
model = Sequential([
    Conv2D(32, 5, padding = 'same', input_shape = (*TARGET_IMAGE_SIZE, 3), activation = LeakyReLU()),
    MaxPooling2D(),

    Conv2D(64, 4, padding = 'same', activation = LeakyReLU()),
    MaxPooling2D(),
    
    Conv2D(128, 3, padding = 'same', activation = LeakyReLU()),
    Dropout(0.1),
    
    UpSampling2D(),
    Conv2D(64, 4, padding = 'same', activation = LeakyReLU()),

    UpSampling2D(),
    Conv2D(32, 5, padding = 'same', activation = LeakyReLU()),

    Dropout(0.1),
    Conv2D(1, 3, padding = 'same', activation = 'sigmoid'),
])

model.compile(optimizer = Adam(LEARNING_RATE), loss = weighted_bce , metrics=['accuracy', 'mse' , 'AUC'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 32)      2432
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 64)      32832
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 128)       73856
#
#  dropout (Dropout)           (None, 64, 64, 128)       0
#
#  up_sampling2d (UpSampling2D  (None, 128, 128, 128)    0
#  )
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 64)      131136
#
#  up_sampling2d_1 (UpSampling  (None, 256, 256, 64)     0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 256, 256, 32)      51232
#
#  dropout_1 (Dropout)         (None, 256, 256, 32)      0
#
#  conv2d_5 (Conv2D)           (None, 256, 256, 1)       289
#
# =================================================================
# Total params: 291,777
# Trainable params: 291,777
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time

history = model.fit(image_data, image_labels, batch_size = BATCH_SIZE, epochs = EPOCHS, validation_split = VAL_SPLIT, verbose = 1)
# Out:
# Epoch 1/50
# 17/17 [==============================] - 4s 249ms/step - loss: 0.8792 - accuracy: 0.6535 - mse: 0.1819 - auc: 0.7779 - val_loss: 0.8022 - val_accuracy: 0.6166 - val_mse: 0.1845 - val_auc: 0.8007
# Epoch 2/50
# 17/17 [==============================] - 4s 245ms/step - loss: 0.8291 - accuracy: 0.6599 - mse: 0.1683 - auc: 0.7928 - val_loss: 0.7892 - val_accuracy: 0.6052 - val_mse: 0.1890 - val_auc: 0.8138
# Epoch 3/50
# 17/17 [==============================] - 4s 249ms/step - loss: 0.8150 - accuracy: 0.6389 - mse: 0.1743 - auc: 0.8051 - val_loss: 0.7575 - val_accuracy: 0.6964 - val_mse: 0.1498 - val_auc: 0.8330
# Epoch 4/50
# 17/17 [==============================] - 4s 252ms/step - loss: 0.8011 - accuracy: 0.6932 - mse: 0.1644 - auc: 0.8135 - val_loss: 0.7514 - val_accuracy: 0.6719 - val_mse: 0.1538 - val_auc: 0.8348
# Epoch 5/50
# 17/17 [==============================] - 4s 250ms/step - loss: 0.7904 - accuracy: 0.6642 - mse: 0.1602 - auc: 0.8192 - val_loss: 0.7457 - val_accuracy: 0.6501 - val_mse: 0.1670 - val_auc: 0.8382
# Epoch 6/50
# 17/17 [==============================] - 4s 251ms/step - loss: 0.7743 - accuracy: 0.7146 - mse: 0.1557 - auc: 0.8295 - val_loss: 0.7485 - val_accuracy: 0.6502 - val_mse: 0.1771 - val_auc: 0.8394
# Epoch 7/50
# 17/17 [==============================] - 4s 255ms/step - loss: 0.8006 - accuracy: 0.6621 - mse: 0.1761 - auc: 0.8107 - val_loss: 0.7502 - val_accuracy: 0.6168 - val_mse: 0.1744 - val_auc: 0.8368
# Epoch 8/50
# 17/17 [==============================] - 4s 256ms/step - loss: 0.7887 - accuracy: 0.6670 - mse: 0.1523 - auc: 0.8230 - val_loss: 0.7355 - val_accuracy: 0.6810 - val_mse: 0.1466 - val_auc: 0.8438
# Epoch 9/50
# 17/17 [==============================] - 4s 258ms/step - loss: 0.7725 - accuracy: 0.6716 - mse: 0.1650 - auc: 0.8282 - val_loss: 0.7276 - val_accuracy: 0.6967 - val_mse: 0.1543 - val_auc: 0.8462
# Epoch 10/50
# 17/17 [==============================] - 4s 262ms/step - loss: 0.7623 - accuracy: 0.6836 - mse: 0.1607 - auc: 0.8355 - val_loss: 0.7255 - val_accuracy: 0.7895 - val_mse: 0.1268 - val_auc: 0.8488
# Epoch 11/50
# 17/17 [==============================] - 4s 264ms/step - loss: 0.7600 - accuracy: 0.6981 - mse: 0.1609 - auc: 0.8343 - val_loss: 0.7207 - val_accuracy: 0.6859 - val_mse: 0.1541 - val_auc: 0.8500
# Epoch 12/50
# 17/17 [==============================] - 4s 261ms/step - loss: 0.7700 - accuracy: 0.6711 - mse: 0.1644 - auc: 0.8267 - val_loss: 0.7266 - val_accuracy: 0.6553 - val_mse: 0.1585 - val_auc: 0.8496
# Epoch 13/50
# 17/17 [==============================] - 4s 262ms/step - loss: 0
# 17/17 [==============================] - 5s 267ms/step - loss: 0.7053 - accuracy: 0.6930 - mse: 0.1560 - auc: 0.8607 - val_loss: 0.6766 - val_accuracy: 0.7601 - val_mse: 0.1395 - val_auc: 0.8670
# Epoch 45/50
# 17/17 [==============================] - 5s 285ms/step - loss: 0.6956 - accuracy: 0.7368 - mse: 0.1512 - auc: 0.8640 - val_loss: 0.6813 - val_accuracy: 0.7492 - val_mse: 0.1331 - val_auc: 0.8671
# Epoch 46/50
# 17/17 [==============================] - 4s 259ms/step - loss: 0.6934 - accuracy: 0.7572 - mse: 0.1411 - auc: 0.8659 - val_loss: 0.6767 - val_accuracy: 0.7552 - val_mse: 0.1451 - val_auc: 0.8666
# Epoch 47/50
# 17/17 [==============================] - 4s 262ms/step - loss: 0.6874 - accuracy: 0.7329 - mse: 0.1469 - auc: 0.8686 - val_loss: 0.6781 - val_accuracy: 0.7416 - val_mse: 0.1356 - val_auc: 0.8668
# Epoch 48/50
# 17/17 [==============================] - 4s 257ms/step - loss: 0.6845 - accuracy: 0.7400 - mse: 0.1451 - auc: 0.8695 - val_loss: 0.6762 - val_accuracy: 0.7400 - val_mse: 0.1448 - val_auc: 0.8680
# Epoch 49/50
# 17/17 [==============================] - 4s 257ms/step - loss: 0.6881 - accuracy: 0.7336 - mse: 0.1468 - auc: 0.8685 - val_loss: 0.6786 - val_accuracy: 0.7441 - val_mse: 0.1483 - val_auc: 0.8659
# Epoch 50/50
# 17/17 [==============================] - 4s 257ms/step - loss: 0.6951 - accuracy: 0.7293 - mse: 0.1499 - auc: 0.8639 - val_loss: 0.6824 - val_accuracy: 0.7485 - val_mse: 0.1298 - val_auc: 0.8677
# CPU times: user 2min 32s, sys: 5.18 s, total: 2min 37s
# Wall time: 4min 22s

# %%
# Metrics of the model
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'mse', 'auc', 'val_loss', 'val_accuracy', 'val_mse', 'val_auc'])

# %%
# Get training and test loss histories
training_loss = history.history['loss']
test_loss = history.history['val_loss']

# Create count of the number of epochs
epoch_count = range(1, len(training_loss) + 1)

# Visualize loss history
plt.plot(epoch_count, training_loss, 'b-')
plt.plot(epoch_count, test_loss, 'r--')
plt.legend(['Training Loss', 'Test Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show();

# %%
# Get training and test loss histories
training_accuracy = history.history['accuracy']
test_accuracy = history.history['val_accuracy']

# Visualize loss history
plt.plot(epoch_count, training_accuracy, 'b-')
plt.plot(epoch_count, test_accuracy, 'c--')
plt.legend(['Training Accuracy', 'Test Accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show();

# %%
# Get training and test loss histories
training_accuracy = history.history['mse']
test_accuracy = history.history['val_mse']

# Visualize loss history
plt.plot(epoch_count, training_accuracy, 'b-')
plt.plot(epoch_count, test_accuracy, 'c--')
plt.legend(['Training MSE', 'Test MSE'])
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.show();

# %%
# Get training and test loss histories
training_accuracy = history.history['auc']
test_accuracy = history.history['val_auc']

# Visualize loss history
plt.plot(epoch_count, training_accuracy, 'b-')
plt.plot(epoch_count, test_accuracy, 'c--')
plt.legend(['Training AUC', 'Test AUC'])
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.show();

# %%
plt.subplots(nrows = 3, ncols = 5, figsize = (20, 10))

indices_to_predict = [81,256,298,73,155]

for i, img_index in enumerate(indices_to_predict):
    preds = model.predict(image_data[indices_to_predict])
    
    masked_images = preds * image_data[indices_to_predict]
    
    plt.subplot(3, 5, i + 1)
    plt.axis(False)
    plt.grid(False)
    plt.title(f'Image: {img_index}')
    plt.imshow(image_data[img_index])
    
    plt.subplot(3, 5, i + 6)
    plt.axis(False)
    plt.grid(False)
    plt.title(f'Predicted mask: {img_index}')
    plt.imshow(preds[i], cmap = 'gray')
    
    plt.subplot(3, 5, i + 11)
    plt.axis(False)
    plt.grid(False)
    plt.title(f'Masked image: {img_index}')
    plt.imshow(masked_images[i])
plt.show()
# Out:
# 1/1 [==============================] - 1s 904ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
